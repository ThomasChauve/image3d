# %% [markdown]
# # Exemples for image3d toolbox
#
# This exemple shows the minimum things to do to autocorrelate a 3D image

# %% [markdown]
# ## Toolbox needed

# %%
import image3d.image3d as image3d
import image3d.xcorr3d as xcorr3d
import image3d.load_data as load_data

# %% [markdown]
# ## Create a 3d black and white image (0 or 1) to build a 3d object
#
# It can be read from tiff file using the function load_data.load_image_from_tiff
#
#
# 0 background and 1 ellipsoidale

# %%
import numpy as np
import time
import matplotlib.pyplot as plt

size=100 #number of voxel size³
center=size/2

ax=size*0.25
ay=size*0.10
az=size*0.25

im=np.zeros([size,size,size])

for i in np.linspace(center-int(ax),center+int(ax),2*int(ax)+1):
    for j in np.linspace(center-int(ay),center+int(ay),2*int(ay)+1):
        for k in np.linspace(center-int(az),center+int(az),2*int(az)+1):
            if ((i-center)**2/(ax**2)+(j-center)**2/(ay**2)+(k-center)**2/(az**2))<1:
                im[int(i),int(j),int(k)]=1

# %% [markdown]
# ## Build the image3d object

# %%
res=1 # resolution of the image, size of the Voxel
data=image3d.image3d(im,res)

# %% [markdown]
# ## Plot one slice of the image

# %%
plt.figure()
data.plot('Y',0.5)
plt.title('Image, Y section, middle')
# Out:
# Text(0.5,1,'Image, Y section, middle')

# %%
plt.figure()
data.plot('Z',0.5)
plt.title('Image, Z section, middle')
# Out:
# Text(0.5,1,'Image, Z section, middle')

# %% [markdown]
# ## Compute the autcorrelation function

# %%
print ('Begining autocorrelation', time.asctime())
autocorr=data.xcorr3d()
print ('End autocorrelation', time.asctime())
# Out:
# Begining autocorrelation Wed Nov  7 14:37:50 2018
# End autocorrelation Wed Nov  7 14:37:50 2018

# %% [markdown]
# ## Plot one slice of autocorrelation function

# %%
autocorr.plot('X',0.5)

# %% [markdown]
# ## Extract Correlation radius for every direction
# Plot it in a pole figure

# %%
print ('Begining stereo proj', time.asctime())
[eigvalue,eigvector,radiusmean,radiusstd,xmin]=autocorr.stereographic_corr_length(coeffCinf=np.array([1.]),pc=15)
print ('End stereo proj', time.asctime())
# Out:
# Begining stereo proj Wed Nov  7 14:37:59 2018
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-c5e9259c6d8e> in <module>()
#       1 print ('Begining stereo proj', time.asctime())
# ----> 2 [eigvalue,eigvector,radiusmean,radiusstd,maxori_angle,meanangle,theta,phi,xmin]=autocorr.stereographic_corr_length(coeffCinf=np.array([1.]),pc=15)
#       3 print ('End stereo proj', time.asctime())
#
# ~/anaconda3/lib/python3.7/site-packages/image3d/xcorr3d.py in stereographic_corr_length(self, output, coeffCinf, pc)
#     106         xcir = np.cos(omega)
#     107         ycir = np.sin(omega)
# --> 108         vcir=setvector3d(np.transpose(np.array([xcir,ycir,zcir])))
#     109
#     110         vtot=vuse.concatenate(vcir)
#
# NameError: name 'setvector3d' is not defined

# %%
val=np.loadtxt('icover.3.78032.51.51.txt')
#val=np.loadtxt('icover.3.10832.19.19.txt')
dim=int(np.size(val)/3)
xx=val.reshape([dim,3])
id=np.where(xx[:,2]>0)
vector=xx[id[0],:]
vecTheta=np.arctan2(vector[:,1],vector[:,0])
vecPhi=np.arccos(vector[:,2])

plt.figure()
yt=plt.hist(vecTheta*180./np.pi,50,range=[-180,180])
plt.xlabel('Theta')
plt.figure()
yp=plt.hist(vecPhi*180./np.pi,50,range=[0,90])
plt.xlabel('Phi')

# %%
plt.figure()
ytr=plt.hist(theta[0]*180./np.pi,50,range=[-180,180])
plt.xlabel('Theta')
plt.figure()
ypr=plt.hist(phi[0]*180./np.pi,50,range=[0,90])
plt.xlabel('Phi')

# %%
plt.figure()
xt=np.arange(-180.,180.,7.2)+3.6
wt=np.ones(50)*7.2

xp=np.arange(0.,90.,1.8)+0.9
wp=np.ones(50)*1.8

plt.bar(xt,ytr[0]/yt[0],wt)
plt.xlabel('Theta')
plt.figure()
plt.bar(xp,ypr[0]/yp[0],wp)
plt.xlabel('Phi')
